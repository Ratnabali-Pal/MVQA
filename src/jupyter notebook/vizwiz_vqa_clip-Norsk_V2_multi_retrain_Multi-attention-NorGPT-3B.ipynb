# %% [markdown]
# # A

# %%
# !pip install git+https://github.com/openai/CLIP.git
# Out:
# Collecting git+https://github.com/openai/CLIP.git
#   Cloning https://github.com/openai/CLIP.git to /tmp/pip-req-build-yfc2qcku
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/CLIP.git /tmp/pip-req-build-yfc2qcku
#   Resolved https://github.com/openai/CLIP.git to commit dcba3cb2e2827b402d2701e7e1c7d9fed8a20ef1
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: ftfy in /home/arif/anaconda3/envs/env_ratnabali/lib/python3.9/site-packages (from clip==1.0) (6.0.3)
# Requirement already satisfied: packaging in /home/arif/anaconda3/envs/env_ratnabali/lib/python3.9/site-packages (from clip==1.0) (24.1)
# Requirement already satisfied: regex in /home/arif/anaconda3/envs/env_ratnabali/lib/python3.9/site-packages (from clip==1.0) (2024.9.11)
# Requirement already satisfied: tqdm in /home/arif/anaconda3/envs/env_ratnabali/lib/python3.9/site-packages (from clip==1.0) (4.66.5)
# Requirement already satisfied: torch in /home/arif/anaconda3/envs/env_ratnabali/lib/python3.9/site-packages (from clip==1.0) (2.4.0)
# Requirement already satisfied: torchvision in /home/arif/anaconda3/envs/env_ratnabali/lib/python3.9/site-packages (from clip==1.0) (0.19.0)
# Requirement already satisfied: wcwidth in /home/arif/anaconda3/envs/env_ratnabali/lib/python3.9/site-packages (from ftfy->clip==1.0) (0.2.13)
# Requirement already satisfied: filelock in /home/arif/anaconda3/envs/env_ratnabali/lib/python3.9/site-packages (from torch->clip==1.0) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /home/arif/anaconda3/envs/env_ratnabali/lib/python3.9/site-packages (from torch->clip==1.0) (4.12.2)
# Requirement already satisfied: sympy in /home/arif/anaconda3/envs/env_ratnabali/lib/python3.9/site-packages (from torch->clip==1.0) (1.13.1)
# Requirement already satisfied: networkx in /home/arif/anaconda3/envs/env_ratnabali/lib/python3.9/site-packages (from torch->clip==1.0) (3.2.1)
# Requirement already satisfied: jinja2 in /home/arif/anaconda3/envs/env_ratnabali/lib/python3.9/site-packages (from torch->clip==1.0) (3.1.4)
# Requirement already satisfied: fsspec in /home/arif/anaconda3/envs/env_ratnabali/lib/python3.9/site-packages (from torch->clip==1.0) (2024.9.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/arif/anaconda3/envs/env_ratnabali/lib/python3.9/site-packages (from torch->clip==1.0) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/arif/anaconda3/envs/env_ratnabali/lib/python3.9/site-packages (from torch->clip==1.0) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/arif/anaconda3/envs/env_ratnabali/lib/python3.9/site-packages (from torch->clip==1.0) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /home/arif/anaconda3/envs/env_ratnabali/lib/python3.9/site-packages (from torch->clip==1.0) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/arif/anaconda3/envs/env_ratnabali/lib/python3.9/site-packages (from torch->clip==1.0) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/arif/anaconda3/envs/env_ratnabali/lib/python3.9/site-packages (from torch->clip==1.0) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/arif/anaconda3/envs/env_ratnabali/lib/python3.9/site-packages (from torch->clip==1.0) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/arif/anaconda3/envs/env_ratnabali/lib/python3.9/site-packages (from torch->clip==1.0) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/arif/anaconda3/envs/env_ratnabali/lib/python3.9/site-packages (from torch->clip==1.0) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /home/arif/anaconda3/envs/env_ratnabali/lib/python3.9/site-packages (from torch->clip==1.0) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/arif/anaconda3/envs/env_ratnabali/lib/python3.9/site-packages (from torch->clip==1.0) (12.1.105)
# Requirement already satisfied: triton==3.0.0 in /home/arif/anaconda3/envs/env_ratnabali/lib/python3.9/site-packages (from torch->clip==1.0) (3.0.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/arif/anaconda3/envs/env_ratnabali/lib/python3.9/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch->clip==1.0) (12.4.127)
# Requirement already satisfied: numpy in /home/arif/anaconda3/envs/env_ratnabali/lib/python3.9/site-packages (from torchvision->clip==1.0) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /home/arif/anaconda3/envs/env_ratnabali/lib/python3.9/site-packages (from torchvision->clip==1.0) (10.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/arif/anaconda3/envs/env_ratnabali/lib/python3.9/site-packages (from jinja2->torch->clip==1.0) (3.0.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/arif/anaconda3/envs/env_ratnabali/lib/python3.9/site-packages (from sympy->torch->clip==1.0) (1.3.0)

# %%
import matplotlib.image as mpimg
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import json
import torch
from collections import Counter
from PIL import Image
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
import torch.optim as optim
from tqdm import tqdm
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
import clip
#from google.colab import drive
import os
from os import listdir
from os.path import isfile, join

# %%
def find_most_common_answer(answers):
    answer_counter = Counter(answers)
    most_common_answers = answer_counter.most_common()
    most_common_answer, count = most_common_answers[0]
    return most_common_answer

def select_most_common_answers(df):
    selected_answers = []
    for idx, row in df.iterrows():
        answers = [answer["answer"] for answer in row["answers"]]
        selected_answer = find_most_common_answer(answers)

        selected_answers.append({"answer": selected_answer
        })

    # Update the "answer" and "answer_confidence" columns in the DataFrame
    df[["answer"]] = pd.DataFrame(selected_answers)

    return df.drop(["answers"], axis=1)

def plot_loss(train_loss, val_loss):
    epochs = range(1, len(train_loss) + 1)

    plt.plot(epochs, train_loss, label='Training Loss')
    plt.plot(epochs, val_loss, label='Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title('Training and Validation Loss')
    plt.legend()
    plt.show()

def plot_img(path):
    # Load the JPEG image
    image = mpimg.imread(path)

    # Plot the image
    plt.imshow(image)
    plt.axis('off')  # Remove axis ticks and labels
    plt.show()

# %%
def dataloader_json(path,test=False):
    # Load the JSON file
    with open(path, 'r') as f:
        data = json.load(f)
    # Create a DataFrame from the loaded JSON data
    df = pd.DataFrame(data)

    if test:
        return df

    return select_most_common_answers(df)

# %%
train_df = dataloader_json("norsk/train_norsk.json")

train_df
# Out:
#                            image  \
# 0      VizWiz_train_00000000.jpg
# 1      VizWiz_train_00000001.jpg
# 2      VizWiz_train_00000002.jpg
# 3      VizWiz_train_00000003.jpg
# 4      VizWiz_train_00000004.jpg
# ...                          ...
# 20518  VizWiz_train_00023949.jpg
# 20519  VizWiz_train_00023950.jpg
# 20520  VizWiz_train_00023951.jpg
# 20521  VizWiz_train_00023952.jpg
# 20522  VizWiz_train_00023953.jpg
#
#                                                 question   answer_type  \
# 0                      Hva er navnet på dette produktet?         other
# 1         Kan du fortelle meg hva som er i denne boksen?         other
# 2      Er dette enchilada saus eller er det tomater? ...         other
# 3                  Hva er captcha på dette skjermbildet?         other
# 4                                Hva er dette elementet?         other
# ...                                                  ...           ...
# 20518                   Hva er fargen på denne laptopen?         other
# 20519  (inaudible) kan du se det? Hvis ja, så fortell...         other
# 20520               Hva er de tre tallene jeg må skrive?  unanswerable
# 20521                                    Er det en boks?        yes/no
# 20522                       Hva er dette i dette bildet?         other
#
#        answerable            answer
# 0               1    basiliumblader
# 1               1              cola
# 2               1           Tomater
# 3               1              t36m
# 4               1    Solens hagelys
# ...           ...               ...
# 20518           1             svart
# 20519           1        Unødvendig
# 20520           0  Unødvendig bilde
# 20521           1               Nei
# 20522           1               Bil
#
# [20523 rows x 5 columns]

# %%
train_df['answer'].value_counts()
# Out:
# answer
# Unødvendig       7488
# Nei               508
# Ja,               500
# Hvit              294
# Grey              286
#                  ...
# 10:37               1
# lammelse            1
# 01 05 13            1
# Boxer scottie       1
# ipseuri ny          1
# Name: count, Length: 5355, dtype: int64

# %%
val_df = dataloader_json("norsk/val_norsk.json")
val_df
# Out:
#                         image  \
# 0     VizWiz_val_00000000.jpg
# 1     VizWiz_val_00000001.jpg
# 2     VizWiz_val_00000002.jpg
# 3     VizWiz_val_00000003.jpg
# 4     VizWiz_val_00000004.jpg
# ...                       ...
# 4314  VizWiz_val_00004314.jpg
# 4315  VizWiz_val_00004315.jpg
# 4316  VizWiz_val_00004316.jpg
# 4317  VizWiz_val_00004317.jpg
# 4318  VizWiz_val_00004318.jpg
#
#                                                question   answer_type  \
# 0     Ok. Det er et annet bilde jeg håper det er et ...  unanswerable
# 1                 Kan du si meg hva denne medisinen er?         other
# 2                       Hva er tittelen på denne boken?         other
# 3                                   Hvilken er den blå?         other
# 4                                       Hva sier pilen?  unanswerable
# ...                                                 ...           ...
# 4314                                      hva er dette?         other
# 4315                                  Er dette moderne?  unanswerable
# 4316  Jeg trenger å kjøpe dette batteriet for min tr...  unanswerable
# 4317                       Hva slags blanding er dette?         other
# 4318                        Hva slags krydder er dette?         other
#
#       answerable          answer
# 0              0      Unødvendig
# 1              1     nattens tid
# 2              1      Hundens år
# 3              1            rett
# 4              0      Unødvendig
# ...          ...             ...
# 4314           1  Salat dressing
# 4315           0      Unødvendig
# 4316           0      Unødvendig
# 4317           1            Kake
# 4318           1    Garam masala
#
# [4319 rows x 5 columns]

# %%
val_df['answer'].nunique()
# Out:
# 1479

# %%
data_df = pd.concat((train_df,val_df), axis =0,ignore_index=True)
data_df
# Out:
#                            image  \
# 0      VizWiz_train_00000000.jpg
# 1      VizWiz_train_00000001.jpg
# 2      VizWiz_train_00000002.jpg
# 3      VizWiz_train_00000003.jpg
# 4      VizWiz_train_00000004.jpg
# ...                          ...
# 24837    VizWiz_val_00004314.jpg
# 24838    VizWiz_val_00004315.jpg
# 24839    VizWiz_val_00004316.jpg
# 24840    VizWiz_val_00004317.jpg
# 24841    VizWiz_val_00004318.jpg
#
#                                                 question   answer_type  \
# 0                      Hva er navnet på dette produktet?         other
# 1         Kan du fortelle meg hva som er i denne boksen?         other
# 2      Er dette enchilada saus eller er det tomater? ...         other
# 3                  Hva er captcha på dette skjermbildet?         other
# 4                                Hva er dette elementet?         other
# ...                                                  ...           ...
# 24837                                      hva er dette?         other
# 24838                                  Er dette moderne?  unanswerable
# 24839  Jeg trenger å kjøpe dette batteriet for min tr...  unanswerable
# 24840                       Hva slags blanding er dette?         other
# 24841                        Hva slags krydder er dette?         other
#
#        answerable          answer
# 0               1  basiliumblader
# 1               1            cola
# 2               1         Tomater
# 3               1            t36m
# 4               1  Solens hagelys
# ...           ...             ...
# 24837           1  Salat dressing
# 24838           0      Unødvendig
# 24839           0      Unødvendig
# 24840           1            Kake
# 24841           1    Garam masala
#
# [24842 rows x 5 columns]

# %%
import matplotlib.pyplot as plt
#Create a figure with six subplots
fig, ((ax1, ax2)) = plt.subplots(1, 2, figsize=(10, 6))

# Plot histogram for 'answerable' with a different color
ax1.hist(pd.concat((train_df,val_df),axis = 0)['answerable'], bins=10, alpha=0.5, color='black', align='mid')
ax1.set_title('Histogram of Answerable')
ax1.set_xlabel('Values')
ax1.set_ylabel('Frequency')

# Plot histogram for 'answer_type' with a different color
ax2.hist(pd.concat((train_df,val_df),axis = 0)['answer_type'], bins=10, alpha=0.5, color='red', align='mid')
ax2.set_title('Histogram of Answer Type')
ax2.set_xlabel('Values')
ax2.set_ylabel('Frequency')

fig.tight_layout()

# Display the plot
plt.show()

# Create the histogram
plt.figure(figsize=(10, 6))  # Adjust the figure size as per your preference
counts, bins, patches = plt.hist(data_df.sample(n=50, random_state=42,replace=False)['answer'], bins=50, color='blue', alpha=0.5)

bin_centers = 0.5 * (bins[:-1] + bins[1:])

# Customize the plot
plt.title('Histogram of Answers')
plt.xlabel('Answers')
plt.ylabel('Frequency')


plt.xticks(rotation=90)

plt.xticks(bin_centers)

max_count = max(counts)
plt.ylim(0, max_count + 1)
# Show the plot
plt.show()

# %%
ans_lb = LabelEncoder()
data_df['answer'] = ans_lb.fit_transform(data_df['answer'])
ans_type_lb = LabelEncoder()
data_df['answer_type']= ans_type_lb.fit_transform(data_df['answer_type'])

# %%
data_df
# Out:
#                            image  \
# 0      VizWiz_train_00000000.jpg
# 1      VizWiz_train_00000001.jpg
# 2      VizWiz_train_00000002.jpg
# 3      VizWiz_train_00000003.jpg
# 4      VizWiz_train_00000004.jpg
# ...                          ...
# 24837    VizWiz_val_00004314.jpg
# 24838    VizWiz_val_00004315.jpg
# 24839    VizWiz_val_00004316.jpg
# 24840    VizWiz_val_00004317.jpg
# 24841    VizWiz_val_00004318.jpg
#
#                                                 question  answer_type  \
# 0                      Hva er navnet på dette produktet?            1
# 1         Kan du fortelle meg hva som er i denne boksen?            1
# 2      Er dette enchilada saus eller er det tomater? ...            1
# 3                  Hva er captcha på dette skjermbildet?            1
# 4                                Hva er dette elementet?            1
# ...                                                  ...          ...
# 24837                                      hva er dette?            1
# 24838                                  Er dette moderne?            2
# 24839  Jeg trenger å kjøpe dette batteriet for min tr...            2
# 24840                       Hva slags blanding er dette?            1
# 24841                        Hva slags krydder er dette?            1
#
#        answerable  answer
# 0               1    4592
# 1               1    4728
# 2               1    4086
# 3               1    5991
# 4               1    3700
# ...           ...     ...
# 24837           1    3421
# 24838           0    4228
# 24839           0    4228
# 24840           1    2184
# 24841           1    1704
#
# [24842 rows x 5 columns]

# %%
#import os
#os.environ['CUDA_VISIBLE_DEVICES'] = '0' 
device = "cuda" if torch.cuda.is_available() else "cpu"
model_clip, preprocess = clip.load("ViT-L/14", device=device)

print(f'Using {device}')
# Out:
# Using cuda

# %%
# !pip install flax
# !pip install jax[cuda11]
# Out:
# Requirement already satisfied: flax in /home/arif/anaconda3/envs/env_ratnabali/lib/python3.9/site-packages (0.8.5)
# Requirement already satisfied: numpy>=1.22 in /home/arif/anaconda3/envs/env_ratnabali/lib/python3.9/site-packages (from flax) (1.26.4)
# Requirement already satisfied: jax>=0.4.27 in /home/arif/anaconda3/envs/env_ratnabali/lib/python3.9/site-packages (from flax) (0.4.30)
# Requirement already satisfied: msgpack in /home/arif/anaconda3/envs/env_ratnabali/lib/python3.9/site-packages (from flax) (1.1.0)
# Requirement already satisfied: optax in /home/arif/anaconda3/envs/env_ratnabali/lib/python3.9/site-packages (from flax) (0.2.4)
# Requirement already satisfied: orbax-checkpoint in /home/arif/anaconda3/envs/env_ratnabali/lib/python3.9/site-packages (from flax) (0.6.4)
# Requirement already satisfied: tensorstore in /home/arif/anaconda3/envs/env_ratnabali/lib/python3.9/site-packages (from flax) (0.1.69)
# Requirement already satisfied: rich>=11.1 in /home/arif/anaconda3/envs/env_ratnabali/lib/python3.9/site-packages (from flax) (13.0.1)
# Requirement already satisfied: typing-extensions>=4.2 in /home/arif/anaconda3/envs/env_ratnabali/lib/python3.9/site-packages (from flax) (4.12.2)
# Requirement already satisfied: PyYAML>=5.4.1 in /home/arif/anaconda3/envs/env_ratnabali/lib/python3.9/site-packages (from flax) (6.0.2)
# Requirement already satisfied: jaxlib<=0.4.30,>=0.4.27 in /home/arif/anaconda3/envs/env_ratnabali/lib/python3.9/site-packages (from jax>=0.4.27->flax) (0.4.30)
# Requirement already satisfied: ml-dtypes>=0.2.0 in /home/arif/anaconda3/envs/env_ratnabali/lib/python3.9/site-packages (from jax>=0.4.27->flax) (0.5.1)
# Requirement already satisfied: opt-einsum in /home/arif/anaconda3/envs/env_ratnabali/lib/python3.9/site-packages (from jax>=0.4.27->flax) (3.4.0)
# Requirement already satisfied: scipy>=1.9 in /home/arif/anaconda3/envs/env_ratnabali/lib/python3.9/site-packages (from jax>=0.4.27->flax) (1.13.1)
# Requirement already satisfied: importlib-metadata>=4.6 in /home/arif/anaconda3/envs/env_ratnabali/lib/python3.9/site-packages (from jax>=0.4.27->flax) (8.5.0)
# Requirement already satisfied: commonmark<0.10.0,>=0.9.0 in /home/arif/anaconda3/envs/env_ratnabali/lib/python3.9/site-packages (from rich>=11.1->flax) (0.9.1)
# Requirement already satisfied: pygments<3.0.0,>=2.6.0 in /home/arif/anaconda3/envs/env_ratnabali/lib/python3.9/site-packages (from rich>=11.1->flax) (2.18.0)
# Requirement already satisfied: absl-py>=0.7.1 in /home/arif/anaconda3/envs/env_ratnabali/lib/python3.9/site-packages (from optax->flax) (2.1.0)
# Requirement already satisfied: chex>=0.1.87 in /home/arif/anaconda3/envs/env_ratnabali/lib/python3.9/site-packages (from optax->flax) (0.1.89)
# Requirement already satisfied: etils[epy] in /home/arif/anaconda3/envs/env_ratnabali/lib/python3.9/site-packages (from optax->flax) (1.5.2)
# Requirement already satisfied: nest_asyncio in /home/arif/anaconda3/envs/env_ratnabali/lib/python3.9/site-packages (from orbax-checkpoint->flax) (1.6.0)
# Requirement already satisfied: protobuf in /home/arif/anaconda3/envs/env_ratnabali/lib/python3.9/site-packages (from orbax-checkpoint->flax) (5.29.1)
# Requirement already satisfied: humanize in /home/arif/anaconda3/envs/env_ratnabali/lib/python3.9/site-packages (from orbax-checkpoint->flax) (4.12.2)
# Requirement already satisfied: toolz>=0.9.0 in /home/arif/anaconda3/envs/env_ratnabali/lib/python3.9/site-packages (from chex>=0.1.87->optax->flax) (1.0.0)
# Requirement already satisfied: zipp>=3.20 in /home/arif/anaconda3/envs/env_ratnabali/lib/python3.9/site-packages (from importlib-metadata>=4.6->jax>=0.4.27->flax) (3.20.2)
# Requirement already satisfied: fsspec in /home/arif/anaconda3/envs/env_ratnabali/lib/python3.9/site-packages (from etils[epath,epy]->orbax-checkpoint->flax) (2024.9.0)
# Requirement already satisfied: importlib_resources in /home/arif/anaconda3/envs/env_ratnabali/lib/python3.9/site-packages (from etils[epath,epy]->orbax-checkpoint->flax) (6.4.5)
# Requirement already satisfied: jax[cuda11] in /home/arif/anaconda3/envs/env_ratnabali/lib/python3.9/site-packages (0.4.30)
# WARNING: jax 0.4.30 does not provide the extra 'cuda11'
# Requirement already satisfied: jaxlib<=0.4.30,>=0.4.27 in /home/arif/anaconda3/envs/env_ratnabali/lib/python3.9/site-packages (from jax[cuda11]) (0.4.30)
# Requirement already satisfied: ml-dtypes>=0.2.0 in /home/arif/anaconda3/envs/env_ratnabali/lib/python3.9/site-packages (from jax[cuda11]) (0.5.1)
# Requirement already satisfied: numpy>=1.22 in /home/arif/anaconda3/envs/env_ratnabali/lib/python3.9/site-packages (from jax[cuda11]) (1.26.4)
# Requirement already satisfied: opt-einsum in /home/arif/anaconda3/envs/env_ratnabali/lib/python3.9/site-packages (from jax[cuda11]) (3.4.0)
# Requirement already satisfied: scipy>=1.9 in /home/arif/anaconda3/envs/env_ratnabali/lib/python3.9/site-packages (from jax[cuda11]) (1.13.1)
# Requirement already satisfied: importlib-metadata>=4.6 in /home/arif/anaconda3/envs/env_ratnabali/lib/python3.9/site-packages (from jax[cuda11]) (8.5.0)
# Requirement already satisfied: zipp>=3.20 in /home/arif/anaconda3/envs/env_ratnabali/lib/python3.9/site-packages (from importlib-metadata>=4.6->jax[cuda11]) (3.20.2)

# %%
# !pip install tf-keras
# Out:
# Requirement already satisfied: tf-keras in /home/arif/anaconda3/envs/env_ratnabali/lib/python3.9/site-packages (2.19.0)
# Requirement already satisfied: tensorflow<2.20,>=2.19 in /home/arif/anaconda3/envs/env_ratnabali/lib/python3.9/site-packages (from tf-keras) (2.19.0)
# Requirement already satisfied: absl-py>=1.0.0 in /home/arif/anaconda3/envs/env_ratnabali/lib/python3.9/site-packages (from tensorflow<2.20,>=2.19->tf-keras) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in /home/arif/anaconda3/envs/env_ratnabali/lib/python3.9/site-packages (from tensorflow<2.20,>=2.19->tf-keras) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /home/arif/anaconda3/envs/env_ratnabali/lib/python3.9/site-packages (from tensorflow<2.20,>=2.19->tf-keras) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /home/arif/anaconda3/envs/env_ratnabali/lib/python3.9/site-packages (from tensorflow<2.20,>=2.19->tf-keras) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /home/arif/anaconda3/envs/env_ratnabali/lib/python3.9/site-packages (from tensorflow<2.20,>=2.19->tf-keras) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /home/arif/anaconda3/envs/env_ratnabali/lib/python3.9/site-packages (from tensorflow<2.20,>=2.19->tf-keras) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /home/arif/anaconda3/envs/env_ratnabali/lib/python3.9/site-packages (from tensorflow<2.20,>=2.19->tf-keras) (3.4.0)
# Requirement already satisfied: packaging in /home/arif/anaconda3/envs/env_ratnabali/lib/python3.9/site-packages (from tensorflow<2.20,>=2.19->tf-keras) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /home/arif/anaconda3/envs/env_ratnabali/lib/python3.9/site-packages (from tensorflow<2.20,>=2.19->tf-keras) (5.29.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /home/arif/anaconda3/envs/env_ratnabali/lib/python3.9/site-packages (from tensorflow<2.20,>=2.19->tf-keras) (2.32.3)
# Requirement already satisfied: setuptools in /home/arif/anaconda3/envs/env_ratnabali/lib/python3.9/site-packages (from tensorflow<2.20,>=2.19->tf-keras) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in /home/arif/anaconda3/envs/env_ratnabali/lib/python3.9/site-packages (from tensorflow<2.20,>=2.19->tf-keras) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /home/arif/anaconda3/envs/env_ratnabali/lib/python3.9/site-packages (from tensorflow<2.20,>=2.19->tf-keras) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /home/arif/anaconda3/envs/env_ratnabali/lib/python3.9/site-packages (from tensorflow<2.20,>=2.19->tf-keras) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /home/arif/anaconda3/envs/env_ratnabali/lib/python3.9/site-packages (from tensorflow<2.20,>=2.19->tf-keras) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /home/arif/anaconda3/envs/env_ratnabali/lib/python3.9/site-packages (from tensorflow<2.20,>=2.19->tf-keras) (1.71.0)
# Requirement already satisfied: tensorboard~=2.19.0 in /home/arif/anaconda3/envs/env_ratnabali/lib/python3.9/site-packages (from tensorflow<2.20,>=2.19->tf-keras) (2.19.0)
# Requirement already satisfied: keras>=3.5.0 in /home/arif/anaconda3/envs/env_ratnabali/lib/python3.9/site-packages (from tensorflow<2.20,>=2.19->tf-keras) (3.9.0)
# Requirement already satisfied: numpy<2.2.0,>=1.26.0 in /home/arif/anaconda3/envs/env_ratnabali/lib/python3.9/site-packages (from tensorflow<2.20,>=2.19->tf-keras) (1.26.4)
# Requirement already satisfied: h5py>=3.11.0 in /home/arif/anaconda3/envs/env_ratnabali/lib/python3.9/site-packages (from tensorflow<2.20,>=2.19->tf-keras) (3.13.0)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.5.1 in /home/arif/anaconda3/envs/env_ratnabali/lib/python3.9/site-packages (from tensorflow<2.20,>=2.19->tf-keras) (0.5.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /home/arif/anaconda3/envs/env_ratnabali/lib/python3.9/site-packages (from tensorflow<2.20,>=2.19->tf-keras) (0.37.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /home/arif/anaconda3/envs/env_ratnabali/lib/python3.9/site-packages (from astunparse>=1.6.0->tensorflow<2.20,>=2.19->tf-keras) (0.44.0)
# Requirement already satisfied: rich in /home/arif/anaconda3/envs/env_ratnabali/lib/python3.9/site-packages (from keras>=3.5.0->tensorflow<2.20,>=2.19->tf-keras) (13.0.1)
# Requirement already satisfied: namex in /home/arif/anaconda3/envs/env_ratnabali/lib/python3.9/site-packages (from keras>=3.5.0->tensorflow<2.20,>=2.19->tf-keras) (0.0.8)
# Requirement already satisfied: optree in /home/arif/anaconda3/envs/env_ratnabali/lib/python3.9/site-packages (from keras>=3.5.0->tensorflow<2.20,>=2.19->tf-keras) (0.14.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/arif/anaconda3/envs/env_ratnabali/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorflow<2.20,>=2.19->tf-keras) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/arif/anaconda3/envs/env_ratnabali/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorflow<2.20,>=2.19->tf-keras) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/arif/anaconda3/envs/env_ratnabali/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorflow<2.20,>=2.19->tf-keras) (1.26.20)
# Requirement already satisfied: certifi>=2017.4.17 in /home/arif/anaconda3/envs/env_ratnabali/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorflow<2.20,>=2.19->tf-keras) (2024.8.30)
# Requirement already satisfied: markdown>=2.6.8 in /home/arif/anaconda3/envs/env_ratnabali/lib/python3.9/site-packages (from tensorboard~=2.19.0->tensorflow<2.20,>=2.19->tf-keras) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /home/arif/anaconda3/envs/env_ratnabali/lib/python3.9/site-packages (from tensorboard~=2.19.0->tensorflow<2.20,>=2.19->tf-keras) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/arif/anaconda3/envs/env_ratnabali/lib/python3.9/site-packages (from tensorboard~=2.19.0->tensorflow<2.20,>=2.19->tf-keras) (3.1.3)
# Requirement already satisfied: importlib-metadata>=4.4 in /home/arif/anaconda3/envs/env_ratnabali/lib/python3.9/site-packages (from markdown>=2.6.8->tensorboard~=2.19.0->tensorflow<2.20,>=2.19->tf-keras) (8.5.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/arif/anaconda3/envs/env_ratnabali/lib/python3.9/site-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow<2.20,>=2.19->tf-keras) (3.0.2)
# Requirement already satisfied: commonmark<0.10.0,>=0.9.0 in /home/arif/anaconda3/envs/env_ratnabali/lib/python3.9/site-packages (from rich->keras>=3.5.0->tensorflow<2.20,>=2.19->tf-keras) (0.9.1)
# Requirement already satisfied: pygments<3.0.0,>=2.6.0 in /home/arif/anaconda3/envs/env_ratnabali/lib/python3.9/site-packages (from rich->keras>=3.5.0->tensorflow<2.20,>=2.19->tf-keras) (2.18.0)
# Requirement already satisfied: zipp>=3.20 in /home/arif/anaconda3/envs/env_ratnabali/lib/python3.9/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard~=2.19.0->tensorflow<2.20,>=2.19->tf-keras) (3.20.2)

# %%
from multilingual_clip import pt_multilingual_clip
from torchvision import transforms
#import transformers
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM
from transformers import AutoTokenizer, AutoModelForMaskedLM, AutoModelForCausalLM
from transformers import T5ForConditionalGeneration, Trainer, TrainingArguments
from transformers import AutoTokenizer, AutoModelForCausalLM

#model_name ='NbAiLab/nb-t5-base-v3'
model_name='NorGLM/NorGPT-3B'

# Load Model & Tokenizer
#model = pt_multilingual_clip.MultilingualCLIP.from_pretrained(model_name)
#tokenizer= AutoTokenizer.from_pretrained(model_name)
tokenizer = AutoTokenizer.from_pretrained("NorGLM/NorGPT-3B")
#model = AutoModelForCausalLM.from_pretrained(model_name, trust_remote_code=True)
#model = AutoModelForMaskedLM.from_pretrained("ltg/norbert3-large", trust_remote_code=True)
#model = AutoModelForSeq2SeqLM.from_pretrained("NorGLM/NorGPT-3B", trust_remote_code=True)
model = AutoModelForCausalLM.from_pretrained("NorGLM/NorGPT-3B", trust_remote_code=True)
#model = AutoModelForMaskedLM.from_pretrained("ltg/norbert3-large", trust_remote_code=True)
#model = T5ForConditionalGeneration.from_pretrained(model_name,from_flax=True)
#tokenizer = transformers.AutoTokenizer.from_pretrained(model_name)
# Out:
# 2025-04-08 17:15:23.209432: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-04-08 17:15:23.216258: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1744125323.223856 1568122 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1744125323.226125 1568122 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1744125323.232053 1568122 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1744125323.232059 1568122 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1744125323.232060 1568122 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1744125323.232061 1568122 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-04-08 17:15:23.234226: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# import torch
# #model_clip.context_length=512
# #encodings = []
# for img , question in tqdm(zip(data_df['image'],data_df['question'])):
#     if "train" in img:
#         image = preprocess(Image.open(f'train/{img}')).unsqueeze(0).to(device)
#     elif "test" in img:
#        image = preprocess(Image.open(f'test/{img}')).unsqueeze(0).to(device)
#     else:
#         image = preprocess(Image.open(f'val/{img}')).unsqueeze(0).to(device)

# encoding = tokenizer(question)

# %%
# # Assuming 'encoding' is already defined and has 'input_ids'
# device = "cuda" if torch.cuda.is_available() else "cpu"

# image_encoding = model_clip.encode_image(image)
# #image_encoding = image_encoding.unsqueeze(0)
# input_tensor = torch.tensor([encoding.input_ids]).to(device)
# # Move model to the same device
# model.to(device)
# text_outputs = model(**{'input_ids': input_tensor})
# # Extracting the logits from the model's output
# logits = text_outputs.logits

# # Creating the output tensor (e.g., applying softmax to get probabilities)
# output_tensor = torch.softmax(logits, dim=1)
# output_tensor = output_tensor.view(1, -1)  # Convert to shape (1, x)

# #text_outputs = model(**[encoding.input_ids])
# #output_tensor = model.generate(input_tensor, decoder_start_token_id=7, eos_token_id=8)
# #tokenizer.decode(output_tensor.squeeze(), skip_special_tokens=True)
# #output_tensor = model.generate(input_tensor, max_new_tokens=50, num_beams=4, do_sample=False)
# #tokenizer.decode(output_tensor.squeeze())
# encodings.append(torch.cat([image_encoding, output_tensor], dim=-1))

# %%
#len(encodings)

# %%
from transformers import OpenAIGPTTokenizer, OpenAIGPTModel
import torch

# %%
import torch
#model_clip.context_length=512
target_length=768
encodings = []
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
for img , question in tqdm(zip(data_df['image'],data_df['question'])):
    if "train" in img:
        image = preprocess(Image.open(f'train/{img}')).unsqueeze(0).to(device)
    elif "test" in img:
       image = preprocess(Image.open(f'test/{img}')).unsqueeze(0).to(device)
    else:
        image = preprocess(Image.open(f'val/{img}')).unsqueeze(0).to(device)

    encoding = tokenizer(question).to(device)

    input_tensor = torch.tensor([encoding.input_ids]).to(device)
    
    output_tensor = model.generate(input_tensor, max_new_tokens=77, decoder_start_token_id=7, eos_token_id=8).to(device)
    
    if output_tensor.shape[1] > target_length:
        # Truncate the encoding
        resized_encoding = output_tensor[:, :target_length]
    else:
        # Pad the encoding with zeros
        padding_length = target_length - output_tensor.shape[1]
        padding = torch.zeros((output_tensor.shape[0], padding_length)).to(output_tensor.device)
        resized_encoding = torch.cat((output_tensor, padding), dim=1)
   
    with torch.no_grad():
        image_encoding = model_clip.encode_image(image).to(device)
        #text_encoding = output_tensor
        #print(text_encoding.shape)
        #print(f"Image encoding device: {image_encoding.device}")
        #print(f"Text encoding device: {output_tensor.device}")

        encodings.append(torch.cat([image_encoding, resized_encoding], dim=-1))
    
    #tokenizer.decode(output_tensor.squeeze(), skip_special_tokens=True)
    # #print(question)
    # #mask_id = tokenizer.convert_tokens_to_ids("[MASK]")
    # input_text = tokenizer(question, return_tensors="pt")
    # output_p = model(**input_text)
    # #output_text = torch.where(input_text.input_ids == mask_id, output_p.logits.argmax(-1), input_text.input_ids)
    
    # input_tensor = torch.tensor(output_text).to(device)
    # # Move model to the same device
    # model.to(device)
    # text_outputs = model(input_tensor)
    # # Extracting the logits from the model's output
    # logits = text_outputs.logits
    
    # # Creating the output tensor (e.g., applying softmax to get probabilities)
    # output_tensor = torch.softmax(logits, dim=1)
    # output_tensor = output_tensor.view(1, -1)  # Convert to shape (1, x)
# Out:
# 0it [00:00, ?it/s]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:8 for open-end generation.
# The attention mask is not set and cannot be inferred from input because pad token is same as eos token. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# 1it [00:01,  1.50s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:8 for open-end generation.
# 2it [00:02,  1.33s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:8 for open-end generation.
# 3it [00:03,  1.28s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:8 for open-end generation.
# 4it [00:05,  1.25s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:8 for open-end generation.
# 5it [00:06,  1.24s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:8 for open-end generation.
# 6it [00:07,  1.23s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:8 for open-end generation.
# 7it [00:08,  1.22s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:8 for open-end generation.
# 8it [00:09,  1.22s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:8 for open-end generation.
# 9it [00:11,  1.22s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:8 for open-end generation.
# 10it [00:12,  1.22s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:8 for open-end generation.
# 11it [00:13,  1.22s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:8 for open-end generation.
# 12it [00:14,  1.22s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:8 for open-end generation.
# 13it [00:16,  1.23s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:8 for open-end generation.
# 14it [00:17,  1.22s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:8 for open-end generation.
# 15it [00:18,  1.23s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:8 for open-end generation.
# 16it [00:19,  1.23s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:8 for open-end generation.
# 17it [00:21,  1.26s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:8 for open-end generation.
# 18it [00:22,  1.24s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:8 for open-end generation.
# 19it [00:23,  1.23s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:8 for open-end generation.
# 20it [00:24,  1.23s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:8 for open-end generation.
# 21it [00:25,  1.22s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:8 for open-end generation.
# 22it [00:27,  1.22s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:8 for open-end generation.
# 23it [00:28,  1.22s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:8 for open-end generation.
# 24it [00:29,  1.21s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:8 for open-end generation.
# 25it [00:30,  1.21s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:8 for open-end generation.
# 26it [00:31,  1.21s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:8 for open-end generation.
# 27it [00:33,  1.21s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:8 for open-end generation.
# 28it [00:34,  1.21s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:8 for open-end generation.
# 29it [00:35,  1.21s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:8 for open-end generation.
# 30it [00:36,  1.21s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:8 for open-end generation.
# 31it [00:38,  1.21s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:8 for open-end generation.
# 32it [00:39,  1.21s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:8 for open-end generation.
# 33it [00:40,  1.21s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:8 for open-end generation.
# 34it [00:41,  1.21s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:8 for open-end generation.
# 35it [00:42,  1.22s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:8 for open-end generation.
# 36it [00:44,  1.21s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:8 for open-end generation.
# 37it [00:45,  1.21s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:8 for open-end generation.
# 38it [00:46,  1.21s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:8 for open-end generation.
# 39it [00:47,  1.21s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:8 for open-end generation.
# 40it [00:48,  1.21s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:8 for open-end generation.
# 41it [00:50,  1.21s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:8 for open-end generation.
# 42it [00:51,  1.21s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:8 for open-end generation.
# 43it [00:52,  1.21s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:8 for open-end generation.
# 44it [00:53,  1.21s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:8 for open-end generation.
# 45it [00:55,  1.21s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:8 for open-end generation.
# 46it [00:56,  1.21s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:8 for open-end generation.
# 47it [00:57,  1.21s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:8 for open-end generation.
# 48it [00:58,  1.21s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:8 for open-end generation.
# 49it [00:59,  1.21s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:8 for open-end generation.
# 50it [01:01,  1.21s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:8 for open-end generation.
# 51it [01:02,  1.21s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:8 for open-end generation.
# 52it [01:03,  1.21s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:8 for open-end generation.
# 53it [01:04,  1.21s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:8 for open-end generation.
# 54it [01:05,  1.21s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:8 for open-end generation.
# 55it [01:07,  1.21s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:8 for open-end generation.
# 56it [01:08,  1.21s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:8 for open-end generation.
# 57it [01:09,  1.21s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:8 for open-end generation.
# 58it [01:10,  1.21s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:8 for open-end generation.
# 59it [01:11,  1.21s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:8 for open-end generation.
# 60it [01:13,  1.21s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:8 for open-end generation.
# 61it [01:14,  1.21s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:8 for open-end generation.
# 62it [01:15,  1.21s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:8 for open-end generation.
# 63it [01:16,  1.21s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:8 for open-end generation.
# 64it [01:18,  1.21s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:8 for open-end generation.
# 65it [01:19,  1.21s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:8 for open-end generation.
# 66it [01:20,  1.20s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:8 for open-end generation.
# 67it [01:21,  1.21s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:8 for open-end generation.
# 68it [01:22,  1.21s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:8 for open-end generation.
# 69it [01:24,  1.21s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:8 for open-end generation.
# 70it [01:25,  1.21s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:8 for open-end generation.
# 71it [01:26,  1.22s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:8 for open-end generation.
# 72it [01:27,  1.22s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:8 for open-end generation.
# 73it [01:28,  1.22s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:8 for open-end generation.
# 74it [01:30,  1.22s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:8 for open-end generation.
# 75it [01:31,  1.21s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:8 for open-end generation.
# 76it [01:32,  1.21s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:8 for open-end generation.
# 77it [01:33,  1.21s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:8 for open-end generation.
# 78it [01:34,  1.21s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:8 for open-end generation.
# 79it [01:36,  1.21s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:8 for open-end generation.
# 80it [01:37,  1.21s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:8 for open-end generation.
# 81it [01:38,  1.21s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:8 for open-end generation.
# 82it [01:39,  1.21s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:8 for open-end generation.
# 83it [01:41,  1.21s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:8 for open-end generation.
# 84it [01:42,  1.21s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:8 for open-end generation.
# 85it [01:43,  1.21s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:8 for open-end generation.
# 86it [01:44,  1.21s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:8 for open-end generation.
# 87it [01:45,  1.21s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:8 for open-end generation.
# 88it [01:47,  1.21s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:8 for open-end generation.
# 89it [01:48,  1.21s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:8 for open-end generation.
# 90it [01:49,  1.21s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:8 for open-end generation.
# 91it [01:50,  1.21s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:8 for open-end generation.
# 92it [01:51,  1.21s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:8 for open-end generation.
# 93it [01:53,  1.21s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:8 for open-end generation.
#
/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:8 for open-end generation.
# 6247it [2:06:02,  1.20s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:8 for open-end generation.
# 6248it [2:06:03,  1.20s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:8 for open-end generation.
# 6249it [2:06:04,  1.20s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:8 for open-end generation.
# 6250it [2:06:05,  1.20s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:8 for open-end generation.

# %%
torch.save(encodings,"model-n.pt")

# %%
len(encodings)
# Out:
# 24842

# %%
# # Determine the maximum length
# max_length = max([encoding.shape[1] for encoding in encodings])

# # Pad the encodings
# padded_encodings = [tokenizer.pad({'input_ids': encoding}, padding='max_length', max_length=max_length, return_tensors='pt') for encoding in encodings]

# # Convert to tensors
# input_tensors = [torch.tensor(encoding['input_ids']).to(device) for encoding in padded_encodings]
# encodings=input_tensor
# torch.save(encodings,"model.pt")

# %%
#encd=torch.load('model-n.pt')

# %%
print(len(data_df))
# Out:
# 24842

# %%
# Generate the indices for train-test split
indices = np.arange(len(data_df))

# Perform train-test split
train_indices, test_indices = train_test_split(indices, test_size=0.05, random_state=42)

# %%
train = data_df.iloc[train_indices] 
train = train.reset_index(drop=True)
train
# Out:
#                            image  \
# 0      VizWiz_train_00017501.jpg
# 1        VizWiz_val_00003817.jpg
# 2      VizWiz_train_00002858.jpg
# 3      VizWiz_train_00004344.jpg
# 4      VizWiz_train_00014612.jpg
# ...                          ...
# 23594    VizWiz_val_00001052.jpg
# 23595  VizWiz_train_00005390.jpg
# 23596  VizWiz_train_00000860.jpg
# 23597  VizWiz_train_00015795.jpg
# 23598    VizWiz_val_00003131.jpg
#
#                                                 question  answer_type  \
# 0                              Hva er inni denne boksen?            2
# 1         Hva er navnet og serienummeret til denne CCTV?            2
# 2                       Hvilken farge er denne skjorten?            1
# 3                                        Hva ser jeg på?            1
# 4      Kan du fortelle meg om det tok bildet av tv-st...            3
# ...                                                  ...          ...
# 23594                                    Hva sier dette?            2
# 23595                           Hva slags brus er dette?            1
# 23596  Er ordet Balm B-a-l-m, skrevet på denne usher-...            3
# 23597                            Hva sier denne skjorta?            1
# 23598                   Hvilken farge er denne skjorten?            1
#
#        answerable  answer
# 0               0    4228
# 1               0    4228
# 2               1    5379
# 3               1    1582
# 4               1    2110
# ...           ...     ...
# 23594           0    4230
# 23595           1    2793
# 23596           1    2863
# 23597           1    5996
# 23598           1    2664
#
# [23599 rows x 5 columns]

# %%
test = data_df.iloc[test_indices]
test = test.reset_index(drop=True)
test
# Out:
#                           image  \
# 0     VizWiz_train_00005163.jpg
# 1     VizWiz_train_00004569.jpg
# 2     VizWiz_train_00023795.jpg
# 3       VizWiz_val_00000320.jpg
# 4     VizWiz_train_00013788.jpg
# ...                         ...
# 1238  VizWiz_train_00003806.jpg
# 1239  VizWiz_train_00004115.jpg
# 1240  VizWiz_train_00004547.jpg
# 1241  VizWiz_train_00019406.jpg
# 1242  VizWiz_train_00010930.jpg
#
#                                                question  answer_type  \
# 0                                Er det lys eller mørk?            1
# 1                                 Hva sier termostaten?            2
# 2     Hva er dette elementet? Hvilket element er dette?            1
# 3                           Hva er skrevet på skjermen?            1
# 4                          Hvem gjør dette merket av kl            1
# ...                                                 ...          ...
# 1238                       Hva står det på denne siden?            2
# 1239                           Hvilken modell er dette?            1
# 1240                    Hva er navnet på denne snacken?            1
# 1241                              Hva er i denne esken?            2
# 1242                                  Hva står det her?            2
#
#       answerable  answer
# 0              1    5531
# 1              0    4228
# 2              1    5367
# 3              1    1761
# 4              1    1352
# ...          ...     ...
# 1238           0    4228
# 1239           1    1549
# 1240           1    1197
# 1241           0    4228
# 1242           0    4228
#
# [1243 rows x 5 columns]

# %%
embedding_size = 768#encodings[0].shape[1] #change by Arif old was 768
classes = len(np.unique(ans_lb.classes_))
aux_classes = len(np.unique(train['answer_type']))
BATCH_SIZE = 64

# %%
classes, aux_classes
# Out:
# (6178, 4)

# %%
encd = torch.load('model-n.pt')
# Out:
# /tmp/ipykernel_1568122/1632734083.py:1: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   encd = torch.load('model-n.pt')

# %%
encd
# Out:
# [tensor([[-0.0977,  0.9229, -0.0142,  ...,  0.0000,  0.0000,  0.0000]],
#         device='cuda:0'),
#  tensor([[0.0223, 0.2235, 0.3984,  ..., 0.0000, 0.0000, 0.0000]],
#         device='cuda:0'),
#  tensor([[ 0.7969,  0.0390, -0.3469,  ...,  0.0000,  0.0000,  0.0000]],
#         device='cuda:0'),
#  tensor([[0.1870, 0.2686, 0.3157,  ..., 0.0000, 0.0000, 0.0000]],
#         device='cuda:0'),
#  tensor([[0.6836, 0.7603, 0.3728,  ..., 0.0000, 0.0000, 0.0000]],
#         device='cuda:0'),
#  tensor([[-0.0789,  0.9604, -0.0210,  ...,  0.0000,  0.0000,  0.0000]],
#         device='cuda:0'),
#  tensor([[-0.4128,  0.9092,  0.6504,  ...,  0.0000,  0.0000,  0.0000]],
#         device='cuda:0'),
#  tensor([[ 0.1583,  0.4614, -0.1934,  ...,  0.0000,  0.0000,  0.0000]],
#         device='cuda:0'),
#  tensor([[0.2195, 0.6108, 0.1169,  ..., 0.0000, 0.0000, 0.0000]],
#         device='cuda:0'),
#  tensor([[-0.3062,  1.0576,  0.3674,  ...,  0.0000,  0.0000,  0.0000]],
#         device='cuda:0'),
#  tensor([[ 0.7446,  0.7339, -0.0970,  ...,  0.0000,  0.0000,  0.0000]],
#         device='cuda:0'),
#  tensor([[0.4915, 0.2247, 0.6470,  ..., 0.0000, 0.0000, 0.0000]],
#         device='cuda:0'),
#  tensor([[ 0.5391,  0.0949, -0.5083,  ...,  0.0000,  0.0000,  0.0000]],
#         device='cuda:0'),
#  tensor([[0.2815, 0.7837, 0.6392,  ..., 0.0000, 0.0000, 0.0000]],
#         device='cuda:0'),
#  tensor([[0.1268, 0.9146, 0.2578,  ..., 0.0000, 0.0000, 0.0000]],
#         device='cuda:0'),
#  tensor([[0.3406, 1.0625, 0.4221,  ..., 0.0000, 0.0000, 0.0000]],
#         device='cuda:0'),
#  tensor([[ 0.1082, -0.0641, -0.7417,  ...,  0.0000,  0.0000,  0.0000]],
#         device='cuda:0'),
#  tensor([[-0.2119, -0.8613,  0.0363,  ...,  0.0000,  0.0000,  0.0000]],
#         device='cuda:0'),
#  tensor([[ 0.6885,  0.2310, -0.3599,  ...,  0.0000,  0.0000,  0.0000]],
#         device='cuda:0'),
#  tensor([[-0.1949,  0.9390,  0.1063,  ...,  0.0000,  0.0000,  0.0000]],
#         device='cuda:0'),
#  tensor([[ 0.8208, -0.1566, -1.0166,  ...,  0.0000,  0.0000,  0.0000]],
#         device='cuda:0'),
#  tensor([[ 0.9570,  0.6631, -0.0132,  ...,  0.0000,  0.0000,  0.0000]],
#         device='cuda:0'),
#  tensor([[ 0.8657,  0.6348, -0.3269,  ...,  0.0000,  0.0000,  0.0000]],
#         device='cuda:0'),
#  tensor([[-0.1659,  0.2366, -0.1809,  ...,  0.0000,  0.0000,  0.0000]],
#         device='cuda:0'),
#  tensor([[ 0.0677,  0.7188, -0.1846,  ...,  0.0000,  0.0000,  0.0000]],
#         device='cuda:0'),
#  tensor([[-0.0284,  0.7480, -0.3845,  ...,  0.0000,  0.0000,  0.0000]],
#         device='cuda:0'),
#  tensor([[ 0.9561,  0.6206, -0.2808,  ...,  0.0000,  0.0000,  0.0000]],
#         device='cuda:0'),
#  tensor([[0.1025, 0.4976, 0.2096,  ..., 0.0000, 0.0000, 0.0000]],
#         device='cuda:0'),
#  tensor([[0.3972, 0.1644, 0.3699,  ..., 0.0000, 0.0000, 0.0000]],
#         device='cuda:0'),
#  tensor([[-0.1221,  0.8125,  0.2041,  ...,  0.0000,  0.0000,  0.0000]],
#         device='cuda:0'),
#  tensor([[-0.2102,  0.6245,  0.0224,  ...,  0.0000,  0.0000,  0.0000]],
#         device='cuda:0'),
#  tensor([[ 0.1750, -0.2930, -0.2209,  ...,  0.0000,  0.0000,  0.0000]],
#         device='cuda:0'),
#  tensor([[0.3530, 0.4326, 0.1155,  ..., 0.0000, 0.0000, 0.0000]],
#         device='cuda:0'),
#  tensor([[-0.0869,  1.1924,  0.1699,  ...,  0.0000,  0.0000,  0.0000]],
#         device='cuda:0'),
#  tensor([[ 1.4111,  0.2144, -0.1185,  ...,  0.0000,  0.0000,  0.0000]],
#         device='cuda:0'),
#  tensor([[ 0.4524,  0.6572, -0.3362,  ...,  0.0000,  0.0000,  0.0000]],
#         device='cuda:0'),
#  tensor([[ 0.4180,  0.4500, -0.2646,  ...,  0.0000,  0.0000,  0.0000]],
#         device='cuda:0'),
#  tensor([[ 0.7651, -0.4519,  0.6802,  ...,  0.0000,  0.0000,  0.0000]],
#         device='cuda:0'),
#  tensor([[ 0.5698,  0.8569, -0.0729,  ...,  0.0000,  0.0000,  0.0000]],
#         device='cuda:0'),
#  tensor([[0.7998, 0.9932, 0.3962,  ..., 0.0000, 0.0000, 0.0000]],
#         device='cuda:0'),
#  tensor([[-0.7612,  0.6626,  0.4700,  ...,  0.0000,  0.0000,  0.0000]],
#         device='cuda:0'),
#  tensor([[-0.0613, -0.1409,  0.4636,  ...,  0.0000,  0.0000,  0.0000]],
#         device='cuda:0'),
#  tensor([[-0.2705,  1.1172,  0.3169,  ...,  0.0000,  0.0000,  0.0000]],
#         device='cuda:0'),
#  tensor([[-0.3550,  0.1294,  0.0986,  ...,  0.0000,  0.0000,  0.0000]],
#         device='cuda:0'),
#  tensor([[ 0.5439,  0.2791, -0.5034,  ...,  0.0000,  0.0000,  0.0000]],
#         device='cuda:0'),
#  tensor([[0.2310, 1.3545, 0.8247,  ..., 0.0000, 0.0000, 0.0000]],
#         device='cuda:0'),
#  tensor([[1.1758, 0.3892, 0.2627,  ..., 0.0000, 0.0000, 0.0000]],
#         device='cuda:0'),
#  tensor([[-0.0268,  0.4011,  0.7451,  ...,  0.0000,  0.0000,  0.0000]],
#         device='cuda:0'),
#  tensor([[-0.4702,  0.3186,  0.7798,  ...,  0.0000,  0.0000,  0.0000]],
#         device='cuda:0'),
#  tensor([[-0.0155,  0.6973,  0.1945,  ...,  0.0000,  0.0000,  0.0000]],
#         device='cuda:0'),
#  tensor([[ 0.5596, -0.1321, -0.0627,  ...,  0.0000,  0.0000,  0.0000]],
#         device='cuda:0'),
#  tensor([[0.8335, 0.7661, 0.6592,  ..., 0.0000, 0.0000, 0.0000]],
#         device='cuda:0'),
#  tensor([[0.5220, 0.2482, 0.1040,  ..., 0.0000, 0.0000, 0.0000]],
#         device='cuda:0'),
#  tensor([[-0.2126,  0.5942,  0.3271,  ...,  0.0000,  0.0000,  0.0000]],
#         device='cuda:0'),
#  tensor([[ 0.3181, -0.0595,  0.0084,  ...,  0.0000,  0.0000,  0.0000]],
#         device='cuda:0'),
#  tensor([[5.9229e-01, 2.9443e-01, 3.2830e-04,  ..., 0.0000e+00, 0.0000e+00,
#           0.0000e+00]], device='cuda:0'),
#  tensor([[ 0.5269,  0.1538, -0.0866,  ...,  0.0000,  0.0000,  0.0000]],
#         device='cuda:0'),
#  tensor([[0.1376, 0.3464, 0.0245,  ..., 0.0000, 0.0000, 0.0000]],
#         device='cuda:0'),
#  tensor([[1.1934, 0.3909, 0.4153,  ..., 0.0000, 0.0000, 0.0000]],
#         device='cuda:0'),
#  tensor([[-0.6118,  0.2371,  0.3997,  ...,  0.0000,  0.0000,  0.0000]],
#         device='cuda:0'),
#  tensor([[0
  ...,  0.0000,  0.0000,  0.0000]],
#         device='cuda:0'),
#  tensor([[0.1957, 0.2859, 0.5708,  ..., 0.0000, 0.0000, 0.0000]],
#         device='cuda:0'),
#  tensor([[ 0.6089,  1.0283, -0.1389,  ...,  0.0000,  0.0000,  0.0000]],
#         device='cuda:0'),
#  tensor([[ 0.5674, -0.5273, -0.1069,  ...,  0.0000,  0.0000,  0.0000]],
#         device='cuda:0'),
#  tensor([[0.9351, 0.5283, 0.1490,  ..., 0.0000, 0.0000, 0.0000]],
#         device='cuda:0'),
#  tensor([[0.1427, 0.2070, 0.0475,  ..., 0.0000, 0.0000, 0.0000]],
#         device='cuda:0'),
#  ...]

# %%
class dataset(Dataset):
    def __init__(self, indices, answers, types, length):
        self.indices = indices
        self.answers = answers
        self.types = types
        self.length = length

    def __getitem__(self, index):
            #print(index)
            if self.length <= 24842:
                return encd[self.indices[index]].float() , torch.tensor(int(self.answers[index])), torch.tensor(int(self.types[index]))
            
            return encd[self.indices[index]].float() , torch.tensor(int(self.answers[index % (self.length/2)])), torch.tensor(int(self.types[index % (self.length/2)]))
            
    def __len__(self):
          return self.length

# %%
encd[0].shape
# Out:
# torch.Size([1, 1536])

# %%
#val = data_df.iloc[24842:].reset_index(drop=True)
#val
#train_indices_aug = train_indices + 24842

# %%
e=torch.cat(encodings).cpu().numpy()
#trainDataset = dataset(np.concatenate((train_indices, train_indices_aug)), train['answer'], train['answer_type'], len(train_indices)*2)
trainDataset = dataset(np.array(range(train_indices.size)), train['answer'] , train['answer_type'], len(train_indices))

valDataset = dataset(np.array(range(test_indices.size)), test['answer'], test['answer_type'], len(test_indices))

#valDataset = dataset(np.array(list(range(encd.shape[0] - 5642, encd.shape[0]))), val['answer'], val['answer_type'], 4319)
#valDataset = dataset(np.array(list(range(encd.shape[0] - 5642, encd.shape[0]))), pd.DataFrame(e).iloc[24842:], val['answer_type'], 5642)

train_dataloader = DataLoader(trainDataset, batch_size = BATCH_SIZE, shuffle = True, num_workers=0)

val_dataloader = DataLoader(valDataset, batch_size = BATCH_SIZE, shuffle = True, num_workers=0)

# %%
len(val_dataloader)
# Out:
# 20

# %%
class Model(nn.Module):
    def __init__(self):
        super(Model, self).__init__()
        self.ln1 = nn.LayerNorm(embedding_size*2)
        self.dp1 = nn.Dropout(0.5)
        self.fc1 = nn.Linear(embedding_size* 2, 512)
        
        self.ln2 = torch.nn.LayerNorm(512)
        self.dp2 = torch.nn.Dropout(0.5)
        
        self.fc2 = torch.nn.Linear(512, classes)
        
        self.fc_aux = torch.nn.Linear(512, aux_classes)
        
        self.lnaux = torch.nn.LayerNorm(aux_classes)
        self.dpaux = torch.nn.Dropout(0.5)
                
        self.fc_gate = torch.nn.Linear(aux_classes, classes)
        self.act_gate = torch.nn.Sigmoid()

    def forward(self, x):
        x = self.ln1(x)
        x = self.dp1(x)
        
        x = x.view(x.size(0), -1)
        x = self.fc1(x)
        
        x = self.ln2(x)
        x = self.dp2(x)
        
#         aux
        aux = self.fc_aux(x)
#         aux = self.lnaux(aux)
#         aux = self.dpaux(aux)
        
#         linear bottom
        vqa = self.fc2(x)
        
        output = vqa * self.act_gate(self.fc_gate(aux))
        
        
        return output,aux

# %%
def run_model(model,dataloader,val_loader, optimizer,train = True ):
    if train:
        model.train()
    
    loss = nn.CrossEntropyLoss()
    
    total_loss = 0
    total_correct = 0
    total_samples = 0
    
    total_correct_ty = 0
    total_samples_ty = 0
    
    for (data, ans , ans_type) in tqdm(dataloader):
        data = data.to(device)
        ans = ans.to(device)
        ans_type = ans_type.to(device)
        optimizer.zero_grad()
        output , aux = model(data)
        
        loss_ans = loss(output, ans)
        loss_type = loss(aux,ans_type)
        loss_combined=loss_ans+loss_type
        total_loss += loss_combined.item()
        loss_combined.backward()
        optimizer.step()
        
        
#         Answer Accurracy
        _, predicted_labels = torch.max(output, dim=1)
        correct = (predicted_labels == ans).sum().item()
        total_correct += correct
        total_samples += ans.size(0)
        train_accuracy = total_correct / total_samples
        
#         Type Accuracy
        _, predicted_labels_ty = torch.max(aux, dim=1)
        correct_ty = (predicted_labels_ty == ans_type).sum().item()
        total_correct_ty += correct_ty
        total_samples_ty += ans_type.size(0)
        train_accuracy_ty = total_correct_ty / total_samples_ty
    
    total_train_accuracy = (train_accuracy + train_accuracy_ty) / 2
        
        
    if val_loader is not None:
        model.eval()

    # Initialize validation-specific variables
    val_loss = 0.0
    total_correct_val=0
    total_samples_val=0
    
    total_correct_val_ty=0
    total_samples_val_ty=0
    
    # Disable gradient calculation
    with torch.no_grad():
        # Iterate over the validation data
        for (data, ans , ans_type) in val_loader:
            data = data.to(device)
            ans = ans.to(device)
            ans_type = ans_type.to(device)
            
            # Forward pass
            output , aux = model(data)

            # Compute the loss
            loss_ans = loss(output, ans)
            loss_type = loss(aux,ans_type)
            loss_combined=loss_ans+loss_type
            val_loss += loss_combined.item()

            # Update validation metrics
            _, val_predicted = torch.max(output, dim=1)
            correct_val = (val_predicted == ans).sum().item()
            total_correct_val += correct_val
            total_samples_val += ans.size(0)
            val_accuracy = total_correct_val / total_samples_val
            
            _, val_predicted_ty = torch.max(aux, dim=1)
            correct_val_ty = (val_predicted_ty == ans_type).sum().item()
            total_correct_val_ty += correct_val_ty
            total_samples_val_ty += ans_type.size(0)
            val_accuracy_ty = total_correct_val_ty / total_samples_val_ty
        
        total_val_accuracy = (val_accuracy + val_accuracy_ty) / 2
        
    train_loss = total_loss/len(dataloader)
    val_loss = val_loss/len(val_loader)
    
    print(f"\nTrain Loss: {train_loss:.4f} | AVG Train ACC: {total_train_accuracy * 100:.4f}% | Val Loss: {val_loss:.4f} | AVG Val ACC: {total_val_accuracy * 100:.2f}%")
    
    print(f"\nTrain ANS ACC: {train_accuracy * 100:.4f}% | VAL ANS ACC: {val_accuracy * 100:.4f}% | Train TYPE ACC: {train_accuracy_ty * 100:.4f}% | VAL TYPE ACC: {val_accuracy_ty * 100:.2f}%\n")
        
    return train_loss, val_loss

# %%
train_dataloader

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
model = Model()
model = model.to(device)
model = nn.DataParallel(model)
epoch = 125
training_loss = []
val_loss = []

optimizer = torch.optim.Adam(model.parameters(),1e-3)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, patience=5, factor=.1, threshold=1e-6)

early_stopping_patience = 15  # Number of epochs to wait for improvement
best_val_loss = float('inf')
epochs_without_improvement = 0

for e in range(epoch):
    print(f'Epoch: {e+1}', f'| LR: { optimizer.param_groups[0]["lr"] }')
    trLoss, vlLoss = run_model(model,train_dataloader,val_dataloader,optimizer)    
    training_loss.append(trLoss)
    val_loss.append(vlLoss)
    
    scheduler.step(vlLoss)
    
    # Check if validation loss has improved
    if vlLoss < best_val_loss:
        best_val_loss = vlLoss
        epochs_without_improvement = 0
    else:
        epochs_without_improvement += 1

    # Check if early stopping criteria met
    if epochs_without_improvement >= early_stopping_patience:
        print(f"\nValidation loss hasn't improved for {early_stopping_patience} epochs. Early stopping.")
        break
# Out:
# Epoch: 1 | LR: 0.001
# 100%|████████████████████████████████████████| 369/369 [00:00<00:00, 732.23it/s]
# Train Loss: 6.9586 | AVG Train ACC: 49.9216% | Val Loss: 6.6608 | AVG Val ACC: 50.97%
#
# Train ANS ACC: 35.8066% | VAL ANS ACC: 35.4787% | Train TYPE ACC: 64.0366% | VAL TYPE ACC: 66.45%
#
# Epoch: 2 | LR: 0.001
# 100%|████████████████████████████████████████| 369/369 [00:00<00:00, 799.20it/s]
# Train Loss: 6.7552 | AVG Train ACC: 51.0361% | Val Loss: 6.9994 | AVG Val ACC: 50.97%
#
# Train ANS ACC: 36.0312% | VAL ANS ACC: 35.4787% | Train TYPE ACC: 66.0409% | VAL TYPE ACC: 66.45%
#
# Epoch: 3 | LR: 0.001
# 100%|████████████████████████████████████████| 369/369 [00:00<00:00, 778.91it/s]
# Train Loss: 6.5011 | AVG Train ACC: 51.0784% | Val Loss: 6.8271 | AVG Val ACC: 50.97%
#
# Train ANS ACC: 36.0609% | VAL ANS ACC: 35.4787% | Train TYPE ACC: 66.0960% | VAL TYPE ACC: 66.45%
#
# Epoch: 4 | LR: 0.001
# 100%|████████████████████████████████████████| 369/369 [00:00<00:00, 762.23it/s]
# Train Loss: 6.3318 | AVG Train ACC: 51.0784% | Val Loss: 6.8788 | AVG Val ACC: 50.97%
#
# Train ANS ACC: 36.0609% | VAL ANS ACC: 35.4787% | Train TYPE ACC: 66.0960% | VAL TYPE ACC: 66.45%
#
# Epoch: 5 | LR: 0.001
# 100%|████████████████████████████████████████| 369/369 [00:00<00:00, 805.38it/s]
# Train Loss: 6.2476 | AVG Train ACC: 51.0806% | Val Loss: 7.0712 | AVG Val ACC: 50.97%
#
# Train ANS ACC: 36.0609% | VAL ANS ACC: 35.4787% | Train TYPE ACC: 66.1003% | VAL TYPE ACC: 66.45%
#
# Epoch: 6 | LR: 0.001
# 100%|████████████████████████████████████████| 369/369 [00:00<00:00, 806.66it/s]
# Train Loss: 6.1931 | AVG Train ACC: 51.0784% | Val Loss: 7.0813 | AVG Val ACC: 50.97%
#
# Train ANS ACC: 36.0609% | VAL ANS ACC: 35.4787% | Train TYPE ACC: 66.0960% | VAL TYPE ACC: 66.45%
#
# Epoch: 7 | LR: 0.001
# 100%|████████████████████████████████████████| 369/369 [00:00<00:00, 782.85it/s]
# Train Loss: 6.1226 | AVG Train ACC: 51.0721% | Val Loss: 7.2086 | AVG Val ACC: 50.97%
#
# Train ANS ACC: 36.0566% | VAL ANS ACC: 35.4787% | Train TYPE ACC: 66.0875% | VAL TYPE ACC: 66.45%
#
# Epoch: 8 | LR: 0.0001
# 100%|████████████████████████████████████████| 369/369 [00:00<00:00, 798.99it/s]
# Train Loss: 5.9643 | AVG Train ACC: 51.0763% | Val Loss: 7.2039 | AVG Val ACC: 50.97%
#
# Train ANS ACC: 36.0566% | VAL ANS ACC: 35.4787% | Train TYPE ACC: 66.0960% | VAL TYPE ACC: 66.45%
#
# Epoch: 9 | LR: 0.0001
# 100%|████████████████████████████████████████| 369/369 [00:00<00:00, 810.45it/s]
# Train Loss: 5.9458 | AVG Train ACC: 51.0721% | Val Loss: 7.2637 | AVG Val ACC: 50.97%
#
# Train ANS ACC: 36.0481% | VAL ANS ACC: 35.4787% | Train TYPE ACC: 66.0960% | VAL TYPE ACC: 66.45%
#
# Epoch: 10 | LR: 0.0001
# 100%|████████████████████████████████████████| 369/369 [00:00<00:00, 756.89it/s]
# Train Loss: 5.9158 | AVG Train ACC: 51.0763% | Val Loss: 7.3216 | AVG Val ACC: 50.97%
#
# Train ANS ACC: 36.0566% | VAL ANS ACC: 35.4787% | Train TYPE ACC: 66.0960% | VAL TYPE ACC: 66.45%
#
# Epoch: 11 | LR: 0.0001
# 100%|████████████████████████████████████████| 369/369 [00:00<00:00, 785.33it/s]
# Train Loss: 5.9037 | AVG Train ACC: 51.0572% | Val Loss: 7.2975 | AVG Val ACC: 50.97%
#
# Train ANS ACC: 36.0185% | VAL ANS ACC: 35.4787% | Train TYPE ACC: 66.0960% | VAL TYPE ACC: 66.45%
#
# Epoch: 12 | LR: 0.0001
# 100%|████████████████████████████████████████| 369/369 [00:00<00:00, 776.55it/s]
# Train Loss: 5.8909 | AVG Train ACC: 51.0636% | Val Loss: 7.3165 | AVG Val ACC: 50.97%
#
# Train ANS ACC: 36.0312% | VAL ANS ACC: 35.4787% | Train TYPE ACC: 66.0960% | VAL TYPE ACC: 66.45%
#
# Epoch: 13 | LR: 0.0001
# 100%|████████████████████████████████████████| 369/369 [00:00<00:00, 783.13it/s]
# Train Loss: 5.8698 | AVG Train ACC: 51.0530% | Val Loss: 7.3910 | AVG Val ACC: 50.97%
#
# Train ANS ACC: 36.0100% | VAL ANS ACC: 35.4787% | Train TYPE ACC: 66.0960% | VAL TYPE ACC: 66.45%
#
# Epoch: 14 | LR: 1e-05
# 100%|████████████████████████████████████████| 369/369 [00:00<00:00, 762.43it/s]
# Train Loss: 5.8507 | AVG Train ACC: 51.0488% | Val Loss: 7.3850 | AVG Val ACC: 50.97%
#
# Train ANS ACC: 36.0015% | VAL ANS ACC: 35.4787% | Train TYPE ACC: 66.0960% | VAL TYPE ACC: 66.45%
#
# Epoch: 15 | LR: 1e-05
# 100%|████████████████████████████████████████| 369/369 [00:00<00:00, 790.34it/s]
# Train Loss: 5.8561 | AVG Train ACC: 51.0339% | Val Loss: 7.4158 | AVG Val ACC: 50.97%
#
# Train ANS ACC: 35.9719% | VAL ANS ACC: 35.4787% | Train TYPE ACC: 66.0960% | VAL TYPE ACC: 66.45%
#
# Epoch: 16 | LR: 1e-05
# 100%|████████████████████████████████████████| 369/369 [00:00<00:00, 771.29it/s]
# Train Loss: 5.8399 | AVG Train ACC: 51.0700% | Val Loss: 7.3834 | AVG Val ACC: 50.97%
#
# Train ANS ACC: 36.0439% | VAL ANS ACC: 35.4787% | Train TYPE ACC: 66.0960% | VAL TYPE ACC: 66.45%
#
#
# Validation loss hasn't improved for 15 epochs. Early stopping.

# %%
testDataset = dataset(test_indices,test['answer'], test['answer_type'],1027)
test_dataloader = DataLoader(testDataset, batch_size=BATCH_SIZE , shuffle=True, num_workers=0)

# %%
loss = nn.CrossEntropyLoss()
model.eval()
test_loss = 0.0
total_correct_test=0
total_samples_test=0
    
total_correct_test_ty=0
total_samples_test_ty=0

# Disable gradient calculation
with torch.no_grad():
    # Iterate over the validation data
    for (data, ans , ans_type) in test_dataloader:
            data = data.to(device)
            ans = ans.to(device)
            ans_type = ans_type.to(device)
            # Forward pass
            output , aux = model(data)

            # Compute the loss
            loss_ans = loss(output, ans)
            loss_type = loss(aux,ans_type)
            loss_combined=loss_ans+loss_type
            test_loss += loss_combined.item()

            # Update validation metrics
            _, test_predicted = torch.max(output, dim=1)
            correct_test = (test_predicted == ans).sum().item()
            total_correct_test += correct_test
            total_samples_test += ans.size(0)
            test_accuracy = total_correct_test / total_samples_test
            
            _, test_predicted_ty = torch.max(aux, dim=1)
            correct_test_ty = (test_predicted_ty == ans_type).sum().item()
            total_correct_test_ty += correct_test_ty
            total_samples_test_ty += ans_type.size(0)
            test_accuracy_ty = total_correct_test_ty / total_samples_test_ty
        
    total_test_accuracy = (test_accuracy + test_accuracy_ty) / 2
        
        
print(f"Test TYPE ACC: {test_accuracy_ty * 100:.4f}% | Test ANS ACC: {test_accuracy * 100:.4f}% | AVG Test ACC: {total_test_accuracy * 100:.4f}% | Test Loss: {test_loss:.4f}")
# Out:
# Test TYPE ACC: 67.0886% | Test ANS ACC: 34.9562% | AVG Test ACC: 51.0224% | Test Loss: 122.2569

# %%
e=torch.cat(encodings).cpu().numpy()
print(e)
pd.DataFrame(e).iloc()
# Out:
# [[-0.09771729  0.92285156 -0.0141983  ...  0.          0.
#    0.        ]
#  [ 0.02229309  0.22351074  0.3984375  ...  0.          0.
#    0.        ]
#  [ 0.796875    0.03903198 -0.34692383 ...  0.          0.
#    0.        ]
#  ...
#  [ 0.35131836  0.5209961   0.25317383 ...  0.          0.
#    0.        ]
#  [ 0.34985352 -0.41088867 -0.27685547 ...  0.          0.
#    0.        ]
#  [-0.06811523  0.05023193  0.01113892 ...  0.          0.
#    0.        ]]

# %%
pd.DataFrame(e).iloc()[1]
# Out:
# 0       0.022293
# 1       0.223511
# 2       0.398438
# 3       0.006718
# 4      -0.394043
#           ...
# 1531    0.000000
# 1532    0.000000
# 1533    0.000000
# 1534    0.000000
# 1535    0.000000
# Name: 1, Length: 1536, dtype: float32

# %%
range(train_indices.size)
# Out:
# range(0, 23599)
