# %%
# !pip install --upgrade google-cloud-translate

# %%
# !pip list
# Out:
# Package                           Version
# --------------------------------- --------------
# absl-py                           2.1.0
# accelerate                        0.32.1
# aiofiles                          24.1.0
# aiohappyeyeballs                  2.4.3
# aiohttp                           3.10.10
# aiohttp-retry                     2.8.3
# aioice                            0.9.0
# aiortc                            1.9.0
# aiosignal                         1.3.1
# aiosqlite                         0.21.0
# annotated-types                   0.7.0
# anthropic                         0.34.2
# anyio                             4.6.2.post1
# APScheduler                       3.11.0
# argon2-cffi                       23.1.0
# argon2-cffi-bindings              21.2.0
# argostranslate                    1.9.6
# arrow                             1.3.0
# asttokens                         3.0.0
# astunparse                        1.6.3
# async-lru                         2.0.4
# ...

# %%
from google.cloud import translate_v2 as translate

# %%
from google.cloud import translate

# %%
from google.oauth2 import service_account

# %%
import json
from google.cloud import translate_v2 as translate

# Initialize the Google Translate client
translate_client = translate.Client()

# Load the training data
with open('norsk/train.json', 'r') as file:
    data = json.load(file)

count = 1
for v in data:
    # Translate the question
    
    t = translate_client.translate(v['question'], source_language='en', target_language='no')
    v['question'] = t['translatedText']
    
    # Translate the answers
    for a in v['answers']:
        ans = translate_client.translate(a['answer'], source_language='en', target_language='no')
        a['answer'] = ans['translatedText']
    
    print(count)
    count += 1
# Out:
# ---------------------------------------------------------------------------
# DefaultCredentialsError                   Traceback (most recent call last)
# Cell In[24], line 5
#       2 from google.cloud import translate_v2 as translate
#       4 # Initialize the Google Translate client
# ----> 5 translate_client = translate.Client()
#       7 # Load the training data
#       8 with open('norsk/train.json', 'r') as file:
#
# File ~/anaconda3/envs/env_ratnabali/lib/python3.9/site-packages/google/cloud/translate_v2/client.py:79, in Client.__init__(self, target_language, credentials, _http, client_info, client_options)
#      70 def __init__(
#      71     self,
#      72     target_language=ENGLISH_ISO_639,
#    (...)
#      76     client_options=None,
#      77 ):
#      78     self.target_language = target_language
# ---> 79     super(Client, self).__init__(credentials=credentials, _http=_http)
#      81     kw_args = {"client_info": client_info}
#      82     if client_options:
#
# ...

# %%
with open('hindi/train_translated.json', 'w') as outfile:
    json.dump(data, outfile, ensure_ascii=False, indent=4)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 with open('hindi/train_translated.json', 'w') as outfile:
# ----> 2     json.dump(data, outfile, ensure_ascii=False, indent=4)
#
# NameError: name 'data' is not defined
